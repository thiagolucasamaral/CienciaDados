# %%
#Leitura de dados com pandas

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('countries_of_the_worldcx.xlsx')

# %%
df
# Out:
#             Country                Region  Population  Area (sq. mi.)  \
# 0       Afghanistan  ASIA (EX. NEAR EAST)    31056997          647500
# 1           Albania        EASTERN EUROPE     3581655           28748
# 2           Algeria       NORTHERN AFRICA    32930091         2381740
# 3    American Samoa               OCEANIA       57794             199
# 4           Andorra        WESTERN EUROPE       71201             468
# ..              ...                   ...         ...             ...
# 222       West Bank             NEAR EAST     2460492            5860
# 223  Western Sahara       NORTHERN AFRICA      273008          266000
# 224           Yemen             NEAR EAST    21456188          527970
# 225          Zambia    SUB-SAHARAN AFRICA    11502010          752614
# 226        Zimbabwe    SUB-SAHARAN AFRICA    12236805          390580
#
#      Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  Net migration  \
# ...

# %%
df.head()
# Out:
#           Country                Region  Population  Area (sq. mi.)  \
# 0     Afghanistan  ASIA (EX. NEAR EAST)    31056997          647500
# 1         Albania        EASTERN EUROPE     3581655           28748
# 2         Algeria       NORTHERN AFRICA    32930091         2381740
# 3  American Samoa               OCEANIA       57794             199
# 4         Andorra        WESTERN EUROPE       71201             468
#
#    Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  Net migration  \
# 0                        48.0                          0.00          23.06
# 1                       124.6                          1.26          -4.93
# 2                        13.8                          0.04          -0.39
# 3                       290.4                         58.29         -20.71
# 4                       152.1                          0.00           6.60
#
#    Infant mortality (per 1000 births)  GDP ($ per capita)  Literacy (%)  \
# ...

# %%
#Manipulação e limpeza de dados com pandas

# %%
df.rename(columns={'countries_of_the_world':'Países','Region':'Continente','Population':'População','Area (sq. mi.)':'Area','Pop. Density (per sq. mi.)':'Densidade populacional', 'Coastline (coast/area ratio)':'Litoral','Net migration':'Taxa de Migração','Infant mortality (per 1000 births)':'Mortalidade Infantil (Por 1000 nasc)','GDP ($ per capita)': 'PIB (per Capita)','Literacy (%)':'Alfabetização(%)','Phones (per 1000)':'Telefones(por 1000)','Arable (%)':'Arável(%)','Crops (%)':'Cultivo (%)','Other (%)':'Outros (%)','Climate':'Clima','Birthrate':'Taxa de Natalidade','Deathrate':'Índice de mortalidade','Agriculture':'Agricultura','Industry':'Industria','Service':'Serviço'})
# Out:
#             Country            Continente  População     Area  \
# 0       Afghanistan  ASIA (EX. NEAR EAST)   31056997   647500
# 1           Albania        EASTERN EUROPE    3581655    28748
# 2           Algeria       NORTHERN AFRICA   32930091  2381740
# 3    American Samoa               OCEANIA      57794      199
# 4           Andorra        WESTERN EUROPE      71201      468
# ..              ...                   ...        ...      ...
# 222       West Bank             NEAR EAST    2460492     5860
# 223  Western Sahara       NORTHERN AFRICA     273008   266000
# 224           Yemen             NEAR EAST   21456188   527970
# 225          Zambia    SUB-SAHARAN AFRICA   11502010   752614
# 226        Zimbabwe    SUB-SAHARAN AFRICA   12236805   390580
#
#      Densidade populacional  Litoral  Taxa de Migração  \
# 0                      48.0     0.00             23.06
# 1                     124.6     1.26             -4.93
# ...

# %%
#Descritivo e exploração de dados com pandas (groupbys)

# %%
media = df.groupby('Region')['Population'].mean()
media
# Out:
# Region
# ASIA (EX. NEAR EAST)    1.317137e+08
# BALTICS                 2.394991e+06
# C.W. OF IND. STATES     2.334013e+07
# EASTERN EUROPE          9.992893e+06
# LATIN AMER. & CARIB     1.248499e+07
# NEAR EAST               1.219177e+07
# NORTHERN AFRICA         2.690119e+07
# NORTHERN AMERICA        6.633446e+07
# OCEANIA                 1.577698e+06
# SUB-SAHARAN AFRICA      1.469484e+07
# WESTERN EUROPE          1.415500e+07
# Name: Population, dtype: float64

# %%
soma = df.groupby('Region')['Population'].sum()

# %%
soma
# Out:
# Region
# ASIA (EX. NEAR EAST)    3687982236
# BALTICS                    7184974
# C.W. OF IND. STATES      280081548
# EASTERN EUROPE           119914717
# LATIN AMER. & CARIB      561824599
# NEAR EAST                195068377
# NORTHERN AFRICA          161407133
# NORTHERN AMERICA         331672307
# OCEANIA                   33131662
# SUB-SAHARAN AFRICA       749437000
# WESTERN EUROPE           396339998
# Name: Population, dtype: int64

# %%
mtw = df

# %%
#Figuras que mostrem insights sobre os dados com pandas e matplotlib

# %%
mtw.plot(x='Region', y='Population', kind='scatter')
plt.show()

# %%
sns.histplot(mtw['Population'])
sns.histplot(mtw['Population'], kde=False)
# Out:
# <AxesSubplot:xlabel='Population', ylabel='Count'>

# %%
mtw['Population'].plot(kind='hist', color='red')
plt.show()

# %%
mtw.plot(x='Deathrate',color='red')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 20 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Country                             227 non-null    object
#  1   Region                              227 non-null    object
#  2   Population                          227 non-null    int64
#  3   Area (sq. mi.)                      227 non-null    int64
#  4   Pop. Density (per sq. mi.)          227 non-null    float64
#  5   Coastline (coast/area ratio)        227 non-null    float64
#  6   Net migration                       224 non-null    float64
#  7   Infant mortality (per 1000 births)  224 non-null    float64
#  8   GDP ($ per capita)                  226 non-null    float64
#  9   Literacy (%)                        209 non-null    float64
#  10  Phones (per 1000)                   223 non-null    float64
# ...

# %%
df.isna().sum()
# Out:
# Country                                0
# Region                                 0
# Population                             0
# Area (sq. mi.)                         0
# Pop. Density (per sq. mi.)             0
# Coastline (coast/area ratio)           0
# Net migration                          3
# Infant mortality (per 1000 births)     3
# GDP ($ per capita)                     1
# Literacy (%)                          18
# Phones (per 1000)                      4
# Arable (%)                             2
# Crops (%)                              2
# Other (%)                              2
# Climate                               22
# Birthrate                              3
# Deathrate                              4
# Agriculture                           15
# Industry                              16
# Service                               15
# dtype: int64

# %%
x = np.linspace(-10, 10, 100)
sig = 1 / (1 + np.exp(-x))
plt.plot(x, sig, "b-", linewidth=2, label=r"$\sigma(x) = \frac{1}{1 + e^{-x}}$")
plt.xlabel("x")
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder as Le
le = Le()
le.fit(df['Country'])
list(le.classes_)
df['Country'] = le.transform(df['Country'])
df.head()
# Out:
#    Country                Region  Population  Area (sq. mi.)  \
# 0        0  ASIA (EX. NEAR EAST)    31056997          647500
# 1        1        EASTERN EUROPE     3581655           28748
# 2        2       NORTHERN AFRICA    32930091         2381740
# 3        3               OCEANIA       57794             199
# 4        4        WESTERN EUROPE       71201             468
#
#    Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  Net migration  \
# 0                        48.0                          0.00          23.06
# 1                       124.6                          1.26          -4.93
# 2                        13.8                          0.04          -0.39
# 3                       290.4                         58.29         -20.71
# 4                       152.1                          0.00           6.60
#
#    Infant mortality (per 1000 births)  GDP ($ per capita)  Literacy (%)  \
# ...

# %%
from sklearn.svm import SVC

clf = SVC(kernel='linear', C=10, random_state=123)
clf.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-371-5bc2ad0db063> in <module>
#       2
#       3 clf = SVC(kernel='linear', C=10, random_state=123)
# ----> 4 clf.fit(X_train, y_train)
#
# c:\users\tamaral\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\svm\_base.py in fit(self, X, y, sample_weight)
#     167             check_consistent_length(X, y)
#     168         else:
# --> 169             X, y = self._validate_data(X, y, dtype=np.float64,
#     170                                        order='C', accept_sparse='csr',
#     171                                        accept_large_sparse=False)
#
# c:\users\tamaral\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
# ...

# %%
from sklearn.preprocessing import StandardScaler
scx = StandardScaler()
df[['Climate', 'Agriculture']] = scx.fit_transform(df[['Climate', 'Agriculture']])
df.head()
# Out:
#    Country                Region  Population  Area (sq. mi.)  \
# 0        0  ASIA (EX. NEAR EAST)    31056997          647500
# 1        1        EASTERN EUROPE     3581655           28748
# 2        2       NORTHERN AFRICA    32930091         2381740
# 3        3               OCEANIA       57794             199
# 4        4        WESTERN EUROPE       71201             468
#
#    Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  Net migration  \
# 0                        48.0                          0.00          23.06
# 1                       124.6                          1.26          -4.93
# 2                        13.8                          0.04          -0.39
# 3                       290.4                         58.29         -20.71
# 4                       152.1                          0.00           6.60
#
#    Infant mortality (per 1000 births)  GDP ($ per capita)  Literacy (%)  \
# ...

# %%
X = df[['Climate','Agriculture']].values
Y = df['Industry'].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.40, random_state=123)

# %%
print('Tamanho de X_train: ', X_train.shape, '\n')
print('Tamanho de X_test: ', X_test.shape, '\n')
print('Tamanho de y_train: ', y_train.shape, '\n')
print('Tamanho de y_test: ', y_test.shape, '\n')
# Out:
# Tamanho de X_train:  (136, 2)
#
# Tamanho de X_test:  (91, 2)
#
# Tamanho de y_train:  (136,)
#
# Tamanho de y_test:  (91,)

# %%
from sklearn.linear_model import SGDClassifier

clf = SGDClassifier(loss='log', learning_rate='constant', max_iter=10,
                   eta0=0.0001, verbose=1, tol=None, random_state=123)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(yteste, yprevisto)

sns.heatmap(cm, annot= True, fmt="d")
plt.xlabel('Expectativa')
plt.ylabel('Realidade')
plt.tight_layout()

# %%
from sklearn.metrics import classification_report

cr = classification_report(y_test, y_test, labels=[0,1])
print (cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.00      0.00      0.00         0
#
#    micro avg       0.00      0.00      0.00         0
#    macro avg       0.00      0.00      0.00         0
# weighted avg       0.00      0.00      0.00         0
# c:\users\tamaral\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\tamaral\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
#Storopoli (2020). Ciência de Dados com Python: pandas, matplotlib, Scikit-Learn, TensorFlow e PyTorch: Ciência de Dados. Retrieved from https://storopoli.io/ciencia-de-dados
