# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('dataset_covid.csv')

# %%
df
# Out:
#    Province/State  Country/Region     Last Update  Confirmed  Deaths  \
# 0           Anhui  Mainland China  1/21/2020 10pm        NaN     NaN
# 1         Beijing  Mainland China  1/21/2020 10pm       10.0     NaN
# 2       Chongqing  Mainland China  1/21/2020 10pm        5.0     NaN
# 3       Guangdong  Mainland China  1/21/2020 10pm       17.0     NaN
# 4         Guangxi  Mainland China  1/21/2020 10pm        NaN     NaN
# 5         Guizhou  Mainland China  1/21/2020 10pm        NaN     NaN
# 6          Hainan  Mainland China  1/21/2020 10pm        NaN     NaN
# 7    Heilongjiang  Mainland China  1/21/2020 10pm        NaN     NaN
# 8           Henan  Mainland China  1/21/2020 10pm        1.0     NaN
# 9       Hong Kong       Hong Kong  1/21/2020 10pm        NaN     NaN
# 10          Hubei  Mainland China  1/21/2020 10pm      270.0     6.0
# 11          Hunan  Mainland China  1/21/2020 10pm        1.0     NaN
# 12        Jiangxi  Mainland China  1/21/2020 10pm        2.0     NaN
# ...

# %%
df.head()
# Out:
#   Province/State  Country/Region     Last Update  Confirmed  Deaths  \
# 0          Anhui  Mainland China  1/21/2020 10pm        NaN     NaN
# 1        Beijing  Mainland China  1/21/2020 10pm       10.0     NaN
# 2      Chongqing  Mainland China  1/21/2020 10pm        5.0     NaN
# 3      Guangdong  Mainland China  1/21/2020 10pm       17.0     NaN
# 4        Guangxi  Mainland China  1/21/2020 10pm        NaN     NaN
#
#    Recovered  Suspected
# 0        NaN        3.0
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        4.0
# 4        NaN        1.0

# %%
df.rename(columns={'Province/State':'Estado','Country/Region':'Pais/Região','Last Update':'Última Atualização','Confirmed':'Casos Confirmado','Deaths':'Mortes', 'Recovered':'Recuperados','Suspected':'Suspeitos'})
# Out:
#           Estado     Pais/Região Última Atualização  Casos Confirmado  Mortes  \
# 0          Anhui  Mainland China     1/21/2020 10pm               NaN     NaN
# 1        Beijing  Mainland China     1/21/2020 10pm              10.0     NaN
# 2      Chongqing  Mainland China     1/21/2020 10pm               5.0     NaN
# 3      Guangdong  Mainland China     1/21/2020 10pm              17.0     NaN
# 4        Guangxi  Mainland China     1/21/2020 10pm               NaN     NaN
# 5        Guizhou  Mainland China     1/21/2020 10pm               NaN     NaN
# 6         Hainan  Mainland China     1/21/2020 10pm               NaN     NaN
# 7   Heilongjiang  Mainland China     1/21/2020 10pm               NaN     NaN
# 8          Henan  Mainland China     1/21/2020 10pm               1.0     NaN
# 9      Hong Kong       Hong Kong     1/21/2020 10pm               NaN     NaN
# 10         Hubei  Mainland China     1/21/2020 10pm             270.0     6.0
# ...

# %%
df.dropna(axis=0, how='any')
# Out:
#    Province/State  Country/Region     Last Update  Confirmed  Deaths  \
# 10          Hubei  Mainland China  1/21/2020 10pm      270.0     6.0
#
#     Recovered  Suspected
# 10       25.0       11.0
